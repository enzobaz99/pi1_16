# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import json

# %% [markdown]
# Cargamos y tranfomamos los datos de games

# %%
data = []
with open('output_steam_games.json') as e:
    for line in e:
        data.append(json.loads(line))
df_games = pd.DataFrame(data)

# %%
df_games
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                       NaN
#
#                                                       url release_date  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                      tags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
# 120444  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                     specs price early_access  \
# 0                                                     NaN   NaN          NaN
# 1                                                     NaN   NaN          NaN
# 2                                                     NaN   NaN          NaN
# 3                                                     NaN   NaN          NaN
# 4                                                     NaN   NaN          NaN
# ...                                                   ...   ...          ...
# 120440                [Single-player, Steam Achievements]  1.99        False
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99        False
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99         True
#
#             id                 developer
# 0          NaN                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4          NaN                       NaN
# ...        ...                       ...
# 120440  773640        Nikita "Ghost_RUS"
# 120441  733530                    Sacada
# 120442  610660  Laush Dmitriy Sergeevich
# 120443  658870             xropi,stev3ns
# 120444  681550                       NaN
#
# [120445 rows x 13 columns]

# %% [markdown]
# Eliminamos los NA

# %%
df_games = df_games.dropna()

# %% [markdown]
# Revisamos como quedo

# %%
df_games.head()
# Out:
#                  publisher                                             genres  \
# 88310            Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311     Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312         Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                 彼岸领域                        [Action, Adventure, Casual]
# 88315  Trickjump Games Ltd                    [Action, Adventure, Simulation]
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88315    Battle Royale Trainer    Battle Royale Trainer
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 88311  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 88312  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 88313     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 88315  http://store.steampowered.com/app/772540/Battl...   2018-01-04
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...
#
#                                              reviews_url  \
# 88310  http://steamcommunity.com/app/761140/reviews/?...
# 88311  http://steamcommunity.com/app/643980/reviews/?...
# 88312  http://steamcommunity.com/app/670290/reviews/?...
# 88313  http://steamcommunity.com/app/767400/reviews/?...
# 88315  http://steamcommunity.com/app/772540/reviews/?...
#
#                                                    specs         price  \
# 88310                                    [Single-player]          4.99
# 88311  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                    [Single-player]          0.99
# 88315                [Single-player, Steam Achievements]          3.99
#
#       early_access      id            developer
# 88310        False  761140            Kotoshiro
# 88311        False  643980     Secret Level SRL
# 88312        False  670290         Poolians.com
# 88313        False  767400                 彼岸领域
# 88315        False  772540  Trickjump Games Ltd

# %% [markdown]
# Revisamos las columnas que no son necesarias

# %%
df_games["id"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 88310     761140
# 88311     643980
# 88312     670290
# 88313     767400
# 88315     772540
#            ...
# 120439    745400
# 120440    773640
# 120441    733530
# 120442    610660
# 120443    658870
# Name: id, Length: 22530, dtype: object>

# %% [markdown]
# Cargamos y transformamos los datos de reviews solo que con un ligero cambio al ver que los datos estan expresados de otra manera

# %%
#Abrimos el archivo "australian_user_reviews.json" en modo lectura ('r') con codificación UTF-8 y lo asigna a la variable w.
#El contexto with se utiliza para garantizar que el archivo se cierre adecuadamente después de su uso.
with open("australian_user_reviews.json", 'r', encoding='utf-8') as w:
    data = w.readlines()
    
datos = [eval(line.strip()) for line in data]

df_review = pd.DataFrame(datos)
df_review.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %% [markdown]
# Al ver que el archivo tiene nudos en otras palabras que no se pudo ver como esperaba desanidamos

# %%
#creo un df con el archivo review y accedo a la columna que me interesa desanidar.
df_reviewsOpen = df_review.explode('reviews')
#con esta expresion creo un nuevo df con la info desanidada en columnas
dfreviewsOpen = pd.concat([df_reviewsOpen.drop(['reviews'], axis=1), df_reviewsOpen['reviews'].apply(pd.Series)], axis=1)

# %% [markdown]
# Al ver que la columna posted esta en un fomrato que es dificil de trabajar prefiero pasarlo a formato datatime y al ver que para el
# pedido que me hicieron solo necesitare año dejo la columna posted como posted year

# %%
# Creamos la columna posted year
dfreviewsOpen['posted year'] = dfreviewsOpen['posted'].str.extract(r'(\d{4})')

# Elimino la columna posted
dfreviewsOpen.drop('posted' , axis = 1, inplace = True)

# %% [markdown]
# Revisamos como quedo

# %%
dfreviewsOpen.head()
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 1            js41637               http://steamcommunity.com/id/js41637
#
#   last_edited item_id                                          helpful  \
# 0                1250                                   No ratings yet
# 0               22200                                   No ratings yet
# 0               43110                                   No ratings yet
# 1              251610  15 of 20 people (75%) found this review helpful
# 1              227300     0 of 1 people (0%) found this review helpful
#
#   recommend                                             review   0 posted year
# 0      True  Simple yet with great replayability. In my opi... NaN        2011
# 0      True               It's unique and worth a playthrough. NaN        2011
# 0      True  Great atmosphere. The gunplay can be a bit chu... NaN        2011
# 1      True  I know what you think when you see this title ... NaN        2014
# 1      True  For a simple (it's actually not all that simpl... NaN        2013

# %% [markdown]
# Visualizo que existe una columna 0 por lo que procedo a eliminarla

# %%
dfreviewsOpen.drop(0 , axis = 1, inplace = True)

# %%
dfreviewsOpen
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                   funny last_edited item_id  \
# 0                                                      1250
# 0                                                     22200
# 0                                                     43110
# 1                                                    251610
# 1                                                    227300
# ...                                 ...         ...     ...
# 25797                                                    70
# 25797                                                362890
# 25798  1 person found this review funny              273110
# 25798                                                   730
# 25798                                                   440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 1      15 of 20 people (75%) found this review helpful      True
# 1         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 25797                                   No ratings yet      True
# 25797                                   No ratings yet      True
# 25798    1 of 2 people (50%) found this review helpful      True
# 25798                                   No ratings yet      True
# 25798                                   No ratings yet      True
#
#                                                   review posted year
# 0      Simple yet with great replayability. In my opi...        2011
# 0                   It's unique and worth a playthrough.        2011
# 0      Great atmosphere. The gunplay can be a bit chu...        2011
# 1      I know what you think when you see this title ...        2014
# 1      For a simple (it's actually not all that simpl...        2013
# ...                                                  ...         ...
# 25797  a must have classic from steam definitely wort...         NaN
# 25797  this game is a perfect remake of the original ...         NaN
# 25798  had so much fun plaing this and collecting res...         NaN
# 25798                                                 :D         NaN
# 25798                                     so much fun :D         NaN
#
# [59333 rows x 9 columns]

# %% [markdown]
# Cargamos y transformamos items

# %%
with open("australian_users_items.json", 'r', encoding='utf-8') as i:
    data = i.readlines()
    
records = [eval(line.strip()) for line in data]

df_item = pd.DataFrame(records)
df_item.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# Desanidamos items

# %%
# Aplico la funcion lambda
df_item['playtime_forever'] = df_item['items'].apply(lambda x: x[0].get('playtime_forever') if len(x) > 0 else 0)
df_item['playtime_2weeks'] = df_item['items'].apply(lambda x: x[0].get('playtime_2weeks') if len(x) > 0 else 0)
df_item['item_name'] = df_item['items'].apply(lambda x: x[0].get('item_name') if len(x) > 0 else 0)
df_item['item_id'] = df_item['items'].apply(lambda x: x[0].get('item_id') if len(x) > 0 else 0)
df_item['playtime_forever'] = df_item['playtime_forever'].astype(int)
df_item['playtime_2weeks'] = df_item['playtime_2weeks'].astype(int)

# %%
df_item.drop(['items'], axis=1, inplace=True)

# %%
df_item
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  playtime_forever  \
# 0      http://steamcommunity.com/profiles/76561197970...                 6
# 1                   http://steamcommunity.com/id/js41637                 0
# 2                 http://steamcommunity.com/id/evcentric               923
# 3                http://steamcommunity.com/id/Riot-Punch                 0
# 4                     http://steamcommunity.com/id/doctr              1131
# ...                                                  ...               ...
# 88305  http://steamcommunity.com/profiles/76561198323...                 0
# 88306  http://steamcommunity.com/profiles/76561198326...                 0
# 88307  http://steamcommunity.com/id/XxLaughingJackClo...                 0
# 88308  http://steamcommunity.com/profiles/76561198329...               677
# 88309     http://steamcommunity.com/id/edward_tremethick                 0
#
#        playtime_2weeks                      item_name item_id
# 0                    0                 Counter-Strike      10
# 1                    0                 Counter-Strike      10
# 2                    0  Red Orchestra: Ostfront 41-45    1200
# 3                    0                 Counter-Strike      10
# 4                    0          Day of Defeat: Source     300
# ...                ...                            ...     ...
# 88305                0          CS:GO Player Profiles  413850
# 88306                0     TrackMania Nations Forever   11020
# 88307                0                              0       0
# 88308              677                       Unturned  304930
# 88309                0                              0       0
#
# [88310 rows x 8 columns]

# %% [markdown]
# Unimos df_item y df_games

# %%
merged_df = pd.merge(df_item, df_games, left_on='item_name', right_on='app_name', how='inner')

# %%
df_completo = pd.merge(merged_df, dfreviewsOpen, on='user_id', how='inner')

# %%
df_completo.head(10)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1  76561197970982479          277  76561197970982479
# 2  76561197970982479          277  76561197970982479
# 3            js41637          888  76561198035864385
# 4            js41637          888  76561198035864385
# 5            js41637          888  76561198035864385
# 6         WeiEDKrSat           28  76561198041660154
# 7        Fr0stedLine           50  76561198037965617
# 8         jarrodtrim          161  76561197999173629
# 9           UTNerd24          188  76561198053985682
#
#                                           user_url_x  playtime_forever  \
# 0  http://steamcommunity.com/profiles/76561197970...                 6
# 1  http://steamcommunity.com/profiles/76561197970...                 6
# 2  http://steamcommunity.com/profiles/76561197970...                 6
# 3               http://steamcommunity.com/id/js41637                 0
# 4               http://steamcommunity.com/id/js41637                 0
# 5               http://steamcommunity.com/id/js41637                 0
# 6            http://steamcommunity.com/id/WeiEDKrSat               328
# 7           http://steamcommunity.com/id/Fr0stedLine               580
# 8            http://steamcommunity.com/id/jarrodtrim               337
# 9              http://steamcommunity.com/id/UTNerd24                 5
#
#    playtime_2weeks       item_name item_id_x publisher    genres  ...  id  \
# 0                0  Counter-Strike        10     Valve  [Action]  ...  10
# 1                0  Counter-Strike        10     Valve  [Action]  ...  10
# 2                0  Counter-Strike        10     Valve  [Action]  ...  10
# 3                0  Counter-Strike        10     Valve  [Action]  ...  10
# 4                0  Counter-Strike        10     Valve  [Action]  ...  10
# 5                0  Counter-Strike        10     Valve  [Action]  ...  10
# 6                0  Counter-Strike        10     Valve  [Action]  ...  10
# 7                0  Counter-Strike        10     Valve  [Action]  ...  10
# 8                0  Counter-Strike        10     Valve  [Action]  ...  10
# 9                0  Counter-Strike        10     Valve  [Action]  ...  10
#
#   developer                                         user_url_y funny  \
# 0     Valve  http://steamcommunity.com/profiles/76561197970...
# 1     Valve  http://steamcommunity.com/profiles/76561197970...
# 2     Valve  http://steamcommunity.com/profiles/76561197970...
# 3     Valve               http://steamcommunity.com/id/js41637
# 4     Valve               http://steamcommunity.com/id/js41637
# 5     Valve               http://steamcommunity.com/id/js41637
# 6     Valve            http://steamcommunity.com/id/WeiEDKrSat
# 7     Valve           http://steamcommunity.com/id/Fr0stedLine
# 8     Valve            http://steamcommunity.com/id/jarrodtrim
# 9     Valve              http://steamcommunity.com/id/UTNerd24
#
#   last_edited item_id_y                                          helpful  \
# 0                  1250                                   No ratings yet
# 1                 22200                                   No ratings yet
# 2                 43110                                   No ratings yet
# 3                251610  15 of 20 people (75%) found this review helpful
# 4                227300     0 of 1 people (0%) found this review helpful
# 5                239030    1 of 4 people (25%) found this review helpful
# 6                  4000     0 of 1 people (0%) found this review helpful
# 7                   220                                   No ratings yet
# 8                   440                                   No ratings yet
# 9                244210   1 of 1 people (100%) found this review helpful
#
#   recommend                                             review posted year
# 0      True  Simple yet with great replayability. In my opi...        2011
# 1      True               It's unique and worth a playthrough.        2011
# 2      True  Great atmosphere. The gunplay can be a bit chu...        2011
# 3      True  I know what you think when you see this title ...        2014
# 4      True  For a simple (it's actually not all that simpl...        2013
# 5      True  Very fun little game to play when your bored o...        2013
# 6      True  es la rajaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        2013
# 7      True                Hermoso juego que nunca olvidare <3         NaN
# 8      True                               Great game. LOVE IT!        2012
# 9      True  This game has TRUE potential to be something o...        2014
#
# [10 rows x 29 columns]

# %%
df_completo.drop(['user_url_y'], axis=1, inplace=True)
df_completo.drop(['early_access'], axis=1, inplace=True)

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Function to assign values according to the scale
def get_sentiment_score(text):
    if pd.isnull(text) or text == '':
        return 1  # Return neutral if it is empty or NaN
    elif isinstance(text, str):
        sentiment = sia.polarity_scores(text)
        compound_score = sentiment['compound']
        if compound_score >= -0.05:
            return 0  # Good score
        elif compound_score <= -0.05:
            return 2  # Bad score
        else:
            return 1
    else:
        return 1  # Return neutral for non-string values


# Convertir la columna 'review' a tipo de dato str
df_completo['review'] = df_completo['review'].astype(str)

# Aplicar la función get_sentiment_score a la columna 'review'
df_completo['sentiment_score'] = df_completo['review'].apply(get_sentiment_score)

# Imprimir el DataFrame actualizado
df_completo
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/enzobaz/nltk_data...
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 1      76561197970982479          277  76561197970982479
# 2      76561197970982479          277  76561197970982479
# 3                js41637          888  76561198035864385
# 4                js41637          888  76561198035864385
# ...                  ...          ...                ...
# 50032  76561198222628548           35  76561198222628548
# 50033        72947282842            2  76561198257767684
# 50034       MeloncraftLP           45  76561198272487068
# 50035       MeloncraftLP           45  76561198272487068
# 50036       MeloncraftLP           45  76561198272487068
#
#                                               user_url_x  playtime_forever  \
# 0      http://steamcommunity.com/profiles/76561197970...                 6
# 1      http://steamcommunity.com/profiles/76561197970...                 6
# 2      http://steamcommunity.com/profiles/76561197970...                 6
# 3                   http://steamcommunity.com/id/js41637                 0
# 4                   http://steamcommunity.com/id/js41637                 0
# ...                                                  ...               ...
# 50032  http://steamcommunity.com/profiles/76561198222...              1222
# 50033           http://steamcommunity.com/id/72947282842                69
# 50034          http://steamcommunity.com/id/MeloncraftLP               799
# 50035          http://steamcommunity.com/id/MeloncraftLP               799
# 50036          http://steamcommunity.com/id/MeloncraftLP               799
#
#        playtime_2weeks                      item_name item_id_x  \
# 0                    0                 Counter-Strike        10
# 1                    0                 Counter-Strike        10
# 2                    0                 Counter-Strike        10
# 3                    0                 Counter-Strike        10
# 4                    0                 Counter-Strike        10
# ...                ...                            ...       ...
# 50032                0           Dungeon Defenders II    236110
# 50033                0        Batman™: Arkham Origins    209000
# 50034                0  The Journey Down: Chapter Two    262850
# 50035                0  The Journey Down: Chapter Two    262850
# 50036                0  The Journey Down: Chapter Two    262850
#
#                                     publisher  \
# 0                                       Valve
# 1                                       Valve
# 2                                       Valve
# 3                                       Valve
# 4                                       Valve
# ...                                       ...
# 50032                    Trendy Entertainment
# 50033  Warner Bros. Interactive Entertainment
# 50034                               SkyGoblin
# 50035                               SkyGoblin
# 50036                               SkyGoblin
#
#                                              genres  ...      id  \
# 0                                          [Action]  ...      10
# 1                                          [Action]  ...      10
# 2                                          [Action]  ...      10
# 3                                          [Action]  ...      10
# 4                                          [Action]  ...      10
# ...                                             ...  ...     ...
# 50032  [Action, Free to Play, Indie, RPG, Strategy]  ...  236110
# 50033                           [Action, Adventure]  ...  209000
# 50034                            [Adventure, Indie]  ...  262850
# 50035                            [Adventure, Indie]  ...  262850
# 50036                            [Adventure, Indie]  ...  262850
#
#                              developer                             funny  \
# 0                                Valve
# 1                                Valve
# 2                                Valve
# 3                                Valve
# 4                                Valve
# ...                                ...                               ...
# 50032             Trendy Entertainment  9 people found this review funny
# 50033  WB Games Montreal,Splash Damage
# 50034                        SkyGoblin  1 person found this review funny
# 50035                        SkyGoblin
# 50036                        SkyGoblin  2 people found this review funny
#
#                   last_edited item_id_y  \
# 0                                  1250
# 1                                 22200
# 2                                 43110
# 3                                251610
# 4                                227300
# ...                       ...       ...
# 50032                            359800
# 50033                               730
# 50034  Last edited August 13.    220090
# 50035                            262850
# 50036                            265630
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 50032  29 of 52 people (56%) found this review helpful      True
# 50033                                   No ratings yet      True
# 50034    3 of 6 people (50%) found this review helpful      True
# 50035     0 of 1 people (0%) found this review helpful      True
# 50036    1 of 15 people (7%) found this review helpful     False
#
#                                                   review posted year  \
# 0      Simple yet with great replayability. In my opi...        2011
# 1                   It's unique and worth a playthrough.        2011
# 2      Great atmosphere. The gunplay can be a bit chu...        2011
# 3      I know what you think when you see this title ...        2014
# 4      For a simple (it's actually not all that simpl...        2013
# ...                                                  ...         ...
# 50032  Okay, You may take this game as "'S***"' But n...        2015
# 50033                                   Prettyy Mad Game        2015
# 50034  GET THIS GAME AND CHAPTER TWO!!!!!!!!!!!!!!!!!...         NaN
# 50035  THIS GAME!!!!!!!!!!!!!!!!!! WOOOOOOOOOOOOOOOOO...         NaN
# 50036  DON'T INSTALL THIS GAME!!!!!!!!!!!!!!!!!!!!!!!...         NaN
#
#       sentiment_score
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 50032               0
# 50033               2
# 50034               0
# 50035               0
# 50036               0
#
# [50037 rows x 28 columns]

# %%
df_completo.drop(['review'], axis=1, inplace=True)
df_completo.drop(['item_id_x'], axis=1, inplace=True)
df_completo.drop(['title'], axis=1, inplace=True)
df_completo.drop(['items_count'], axis=1, inplace=True)
df_completo.drop(['steam_id'], axis=1, inplace=True)
df_completo.drop(['user_url_x'], axis=1, inplace=True)
df_completo.drop(['playtime_2weeks'], axis=1, inplace=True)
df_completo.drop(['item_name'], axis=1, inplace=True)
df_completo.drop(['publisher'], axis=1, inplace=True)
df_completo.drop(['url'], axis=1, inplace=True)
df_completo.drop(['reviews_url'], axis=1, inplace=True)
df_completo.drop(['specs'], axis=1, inplace=True)
df_completo.drop(['funny'], axis=1, inplace=True)
df_completo.drop(['last_edited'], axis=1, inplace=True)
df_completo.drop(['helpful'], axis=1, inplace=True)

# %%
df_completo.columns
# Out:
# Index(['user_id', 'playtime_forever', 'genres', 'app_name', 'release_date',
#        'tags', 'price', 'id', 'developer', 'item_id_y', 'recommend',
#        'posted year', 'sentiment_score'],
#       dtype='object')

# %%
df_completo= df_completo.dropna()

# %%
df_completo.to_csv('df_completo.csv', index=False)

# %%
df_completo['user_id'].value_counts()
# Out:
# user_id
# OfficialSenix        40
# 76561198064484479    36
# chicken_tonight      36
# nitr0ticwolf         36
# 76561198063316459    36
#                      ..
# 2ik4tf                1
# jubjub727             1
# 76561198061493090     1
# KappaKaiju            1
# 72947282842           1
# Name: count, Length: 18096, dtype: int64

# %%
df_games.rename(columns={'id': 'item_id'}, inplace=True)
# Out:
# /tmp/ipykernel_25623/3117774538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_games.rename(columns={'id': 'item_id'}, inplace=True)

# %%
df_completo_itemid = pd.merge(df_games, pd.merge(df_item, dfreviewsOpen, on='item_id', how='inner'), on='item_id', how='inner')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_completo_itemid.columns
# Out:
# Index(['publisher', 'genres', 'app_name', 'title', 'url', 'release_date',
#        'tags', 'reviews_url', 'specs', 'price', 'early_access', 'item_id',
#        'developer', 'user_id_x', 'items_count', 'steam_id', 'user_url_x',
#        'playtime_forever', 'playtime_2weeks', 'item_name', 'user_id_y',
#        'user_url_y', 'funny', 'last_edited', 'helpful', 'recommend', 'review',
#        'posted year'],
#       dtype='object')
